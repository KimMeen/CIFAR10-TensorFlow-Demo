# %% [markdown]
# ### Silverpond Internship Test
# + Playing with convolutions: A notebook that looks at convolutions, purely independently of deep learning, and tests a few different varieties on images.
# + Ming Jin >>> <mingj2@student.unimelb.edu.au>
#
# #### Step1-Training.ipynb >>> this is the main gate for starting the training
#
# #### Important Notices:
# + This version is based on my previous works, find out more via this link:  <https://github.com/KimMeen/CIFAR10-Tensorflow-Single-Image-Test>

# %%
import tensorflow as tf
import Preprocessing as pre
import numpy
import time
import matplotlib.pyplot as plt
# Out:
# /Users/kimmeen/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# + import tensorflow and some other libraries
#
# + Initialise some arguments before the training
#
# + loading the data via data helper(Preprocessing.py)

# %%
cifar10 = pre.read_data_sets('./cifar-10/')
iterration = 15001
batch_size = 128
lr1 = 0.1
lr2 = 0.01
lr3 = 0.001
lr4 = 0.0001
image_size = 24
# Out:
# 50000
# processing 0: ./cifar-10/train/0/0_10008.jpg
# processing 100: ./cifar-10/train/0/0_10952.jpg
# processing 200: ./cifar-10/train/0/0_11783.jpg
# processing 300: ./cifar-10/train/0/0_1260.jpg
# processing 400: ./cifar-10/train/0/0_13489.jpg
# processing 500: ./cifar-10/train/0/0_14468.jpg
# processing 600: ./cifar-10/train/0/0_15502.jpg
# processing 700: ./cifar-10/train/0/0_16391.jpg
# processing 800: ./cifar-10/train/0/0_17221.jpg
# processing 900: ./cifar-10/train/0/0_18271.jpg
# processing 1000: ./cifar-10/train/0/0_19106.jpg
# processing 1100: ./cifar-10/train/0/0_20070.jpg
# processing 1200: ./cifar-10/train/0/0_20980.jpg
# processing 1300: ./cifar-10/train/0/0_21924.jpg
# processing 1400: ./cifar-10/train/0/0_2287.jpg
# processing 1500: ./cifar-10/train/0/0_23830.jpg
# processing 1600: ./cifar-10/train/0/0_24600.jpg
# processing 1700: ./cifar-10/train/0/0_25419.jpg
# processing 1800: ./cifar-10/train/0/0_26311.jpg
# processing 1900: ./cifar-10/train/0/0_27286.jpg
# processing 2000: ./cifar-10/train/0/0_28231.jpg
# processing 2100: ./cifar-10/train/0/0_29232.jpg
# processing 2200: ./cifar-10/train/0/0_30078.jpg
# processing 2300: ./cifar-10/train/0/0_30968.jpg
# processing 2400: ./cifar-10/train/0/0_32081.jpg
# processing 2500: ./cifar-10/train/0/0_3295.jpg
# processing 2600: ./cifar-10/train/0/0_33764.jpg
# processing 2700: ./cifar-10/train/0/0_34724.jpg
# processing 2800: ./cifar-10/train/0/0_35594.jpg
# processing 2900: ./cifar-10/train/0/0_36415.jpg
# processing 3000: ./cifar-10/train/0/0_37324.jpg
# processing 3100: ./cifar-10/train/0/0_38217.jpg
# processing 3200: ./cifar-10/train/0/0_39037.jpg
# processing 3300: ./cifar-10/train/0/0_39914.jpg
# processing 3400: ./cifar-10/train/0/0_4079.jpg
# processing 3500: ./cifar-10/train/0/0_41731.jpg
# processing 3600: ./cifar-10/train/0/0_42576.jpg
# processing 3700: ./cifar-10/train/0/0_43508.jpg
# processing 3800: ./cifar-10/train/0/0_44319.jpg
# processing 3900: ./cifar-10/train/0/0_45102.jpg
# processing 4000: ./cifar-10/train/0/0_46019.jpg
# processing 4100: ./cifar-10/train/0/0_46935.jpg
# processing 4200: ./cifar-10/train/0/0_47754.jpg
# processing 4300: ./cifar-10/train/0/0_48557.jpg
# processing 4400: ./cifar-10/train/0/0_49507.jpg
# processing 4500: ./cifar-10/train/0/0_5529.jpg
# processing 4600: ./cifar-10/train/0/0_6380.jpg
# processing 4700: ./cifar-10/train/0/0_7464.jpg
# processing 4800: ./cifar-10/train/0/0_8217.jpg
# processing 4900: ./cifar-10/train/0/0_911.jpg
# processing 5000: ./cifar-10/train/1/1_10000.jpg
# processing 5100: ./cifar-10/train/1/1_1090.jpg
# processing 5200: ./cifar-10/train/1/1_11910.jpg
# processing 5300: ./cifar-10/train/1/1_12800.jpg
# processing 5400: ./cifar-10/train/1/1_13608.jpg
# processing 5500: ./cifar-10/train/1/1_14451.jpg
# processing 5600: ./cifar-10/train/1/1_15462.jpg
# processing 5700: ./cifar-10/train/1/1_16197.jpg
# processing 5800: ./cifar-10/train/1/1_17008.jpg
# processing 5900: ./cifar-10/train/1/1_17970.jpg
# processing 6000: ./cifar-10/train/1/1_19054.jpg
# processing 6100: ./cifar-10/train/1/1_2005.jpg
# processing 6200: ./cifar-10/train/1/1_20858.jpg
# processing 6300: ./cifar-10/train/1/1_21685.jpg
# processing 6400: ./cifar-10/train/1/1_22500.jpg
# processing 6500: ./cifar-10/train/1/1_23280.jpg
# processing 6600: ./cifar-10/train/1/1_24219.jpg
# processing 6700: ./cifar-10/train/1/1_25050.jpg
# processing 6800: ./cifar-10/train/1/1_26059.jpg
# processing 6900: ./cifar-10/train/1/1_27019.jpg
# processing 7000: ./cifar-10/train/1/1_2802.jpg
# processing 7100: ./cifar-10/train/1/1_28798.jpg
# processing 7200: ./cifar-10/train/1/1_29576.jpg
# processing 7300: ./cifar-10/train/1/1_304.jpg
# processing 7400: ./cifar-10/train/1/1_31274.jpg
# processing 7500: ./cifar-10/train/1/1_3233.jpg
# processing 7600: ./cifar-10/train/1/1_33392.jpg
# processing 7700: ./cifar-10/train/1/1_34300.jpg
# processing 7800: ./cifar-10/train/1/1_35174.jpg
# processing 7900: ./cifar-10/train/1/1_36102.jpg
# processing 8000: ./cifar-10/train/1/1_37203.jpg
# processing 8100: ./cifar-10/train/1/1_38152.jpg
# processing 8200: ./cifar-10/train/1/1_39039.jpg
# processing 8300: ./cifar-10/train/1/1_39953.jpg
# processing 8400: ./cifar-10/train/1/1_4084.jpg
# processing 8500: ./cifar-10/train/1/1_41706.jpg
# processing 8600: ./cifar-10/train/1/1_42625.jpg
# processing 8700: ./cifar-10/train/1/1_43480.jpg
# processing 8800: ./cifar-10/train/1/1_44311.jpg
# processing 8900: ./cifar-10/train/1/1_45105.jpg
# processing 9000: ./cifar-10/train/1/1_45988.jpg
# processing 9100: ./cifar-10/train/1/1_46914.jpg
# processing 9200: ./cifar-10/train/1/1_4797.jpg
# processing 9300: ./cifar-10/train/1/1_49075.jpg
# processing 9400: ./cifar-10/train/1/1_49769.jpg
# processing 9500: ./cifar-10/train/1/1_5714.jpg
# processing 9600: ./cifar-10/train/1/1_6661.jpg
# processing 9700: ./cifar-10/train/1/1_7430.jpg
# processing 9800: ./cifar-10/train/1/1_833.jpg
# processing 9900: ./cifar-10/train/1/1_9189.jpg
# processing 10000: ./cifar-10/train/2/2_10018.jpg
# processing 10100: ./cifar-10/train/2/2_11084.jpg
# processing 10200: ./cifar-10/train/2/2_11934.jpg
# processing 10300: ./cifar-10/train/2/2_12752.jpg
# processing 10400: ./cifar-10/train/2/2_13640.jpg
# processing 10500: ./cifar-10/train/2/2_14426.jpg
# processing 10600: ./cifar-10/train/2/2_15289.jpg
# processing 10700: ./cifar-10/train/2/2_16165.jpg
# processing 10800: ./cifar-10/train/2/2_17117.jpg
# processing 10900: ./cifar-10/train/2/2_1793.jpg
# processing 11000: ./cifar-10/train/2/2_18855.jpg
# processing 11100: ./cifar-10/train/2/2_1981.jpg
# processing 11200: ./cifar-10/train/2/2_20724.jpg
# processing 11300: ./cifar-10/train/2/2_2163.jpg
# processing 11400: ./cifar-10/train/2/2_22571.jpg
# processing 11500: ./cifar-10/train/2/2_2349.jpg
# processing 11600: ./cifar-10/train/2/2_24569.jpg
# processing 11700: ./cifar-10/train/2/2_25367.jpg
# processing 11800: ./cifar-10/train/2/2_26242.jpg
# processing 11900: ./cifar-10/train/2/2_27149.jpg
# processing 12000: ./cifar-10/train/2/2_28043.jpg
# processing 12100: ./cifar-10/train/2/2_28933.jpg
# processing 12200: ./cifar-10/train/2/2_29885.jpg
# processing 12300: ./cifar-10/train/2/2_30680.jpg
# processing 12400: ./cifar-10/train/2/2_31493.jpg
# processing 12500: ./cifar-10/train/2/2_32430.jpg
# processing 12600: ./cifar-10/train/2/2_33310.jpg
# processing 12700: ./cifar-10/train/2/2_34196.jpg
# processing 12800: ./cifar-10/train/2/2_35022.jpg
# processing 12900: ./cifar-10/train/2/2_35834.jpg
# processing 13000: ./cifar-10/train/2/2_36524.jpg
# processing 13100: ./cifar-10/train/2/2_37464.jpg
# processing 13200: ./cifar-10/train/2/2_3845.jpg
# processing 13300: ./cifar-10/train/2/2_39492.jpg
# processing 13400: ./cifar-10/train/2/2_40305.jpg
# processing 13500: ./cifar-10/train/2/2_41273.jpg
# processing 13600: ./cifar-10/train/2/2_42158.jpg
# processing 13700: ./cifar-10/train/2/2_43118.jpg
# processing 13800: ./cifar-10/train/2/2_44121.jpg
# processing 13900: ./cifar-10/train/2/2_45023.jpg
# processing 14000: ./cifar-10/train/2/2_45980.jpg
# processing 14100: ./cifar-10/train/2/2_46870.jpg
# processing 14200: ./cifar-10/train/2/2_47800.jpg
# processing 14300: ./cifar-10/train/2/2_48598.jpg
# processing 14400: ./cifar-10/train/2/2_49721.jpg
# processing 14500: ./cifar-10/train/2/2_5634.jpg
# processing 14600: ./cifar-10/train/2/2_6520.jpg
# processing 14700: ./cifar-10/train/2/2_7480.jpg
# processing 14800: ./cifar-10/train/2/2_8264.jpg
# processing 14900: ./cifar-10/train/2/2_9191.jpg
# processing 15000: ./cifar-10/train/3/3_10005.jpg
# processing 15100: ./cifar-10/train/3/3_10931.jpg
# processing 15200: ./cifar-10/train/3/3_11655.jpg
# processing 15300: ./cifar-10/train/3/3_12639.jpg
# processing 15400: ./cifar-10/train/3/3_13595.jpg
# processing 15500: ./cifar-10/train/3/3_14536.jpg
# processing 15600: ./cifar-10/train/3/3_15411.jpg
# processing 15700: ./cifar-10/train/3/3_16360.jpg
# processing 15800: ./cifar-10/train/3/3_17184.jpg
# processing 15900: ./cifar-10/train/3/3_1815.jpg
# processing 16000: ./cifar-10/train/3/3_19060.jpg
# processing 16100: ./cifar-10/train/3/3_19895.jpg
# processing 16200: ./cifar-10/train/3/3_20626.jpg
# processing 16300: ./cifar-10/train/3/3_21640.jpg
# processing 16400: ./cifar-10/train/3/3_2254.jpg
# processing 16500: ./cifar-10/train/3/3_23376.jpg
# processing 16600: ./cifar-10/train/3/3_24262.jpg
# processing 16700: ./cifar-10/train/3/3_25219.jpg
# processing 16800: ./cifar-10/train/3/3_25997.jpg
# processing 16900: ./cifar-10/train/3/3_26934.jpg
# processing 17000: ./cifar-10/train/3/3_27831.jpg
# processing 17100: ./cifar-10/train/3/3_28880.jpg
# processing 17200: ./cifar-10/train/3/3_29950.jpg
# processing 17300: ./cifar-10/train/3/3_30986.jpg
# processing 17400: ./cifar-10/train/3/3_3194.jpg
# processing 17500: ./cifar-10/train/3/3_32914.jpg
# processing 17600: ./cifar-10/train/3/3_3385.jpg
# processing 17700: ./cifar-10/train/3/3_34710.jpg
# processing 17800: ./cifar-10/train/3/3_35541.jpg
# processing 17900: ./cifar-10/train/3/3_36527.jpg
# processing 18000: ./cifar-10/train/3/3_37350.jpg
# processing 18100: ./cifar-10/train/3/3_3818.jpg
# processing 18200: ./cifar-10/train/3/3_39130.jpg
# processing 18300: ./cifar-10/train/3/3_4007.jpg
# processing 18400: ./cifar-10/train/3/3_41027.jpg
# processing 18500: ./cifar-10/train/3/3_41910.jpg
# processing 18600: ./cifar-10/train/3/3_42773.jpg
# processing 18700: ./cifar-10/train/3/3_43716.jpg
# processing 18800: ./cifar-10/train/3/3_44513.jpg
# processing 18900: ./cifar-10/train/3/3_45439.jpg
# processing 19000: ./cifar-10/train/3/3_46352.jpg
# processing 19100: ./cifar-10/train/3/3_47219.jpg
# processing 19200: ./cifar-10/train/3/3_48112.jpg
# processing 19300: ./cifar-10/train/3/3_49078.jpg
# processing 19400: ./cifar-10/train/3/3_49840.jpg
# processing 19500: ./cifar-10/train/3/3_583.jpg
# processing 19600: ./cifar-10/train/3/3_6649.jpg
# processing 19700: ./cifar-10/train/3/3_7467.jpg
# processing 19800: ./cifar-10/train/3/3_8210.jpg
# processing 19900: ./cifar-10/train/3/3_9129.jpg
# processing 20000: ./cifar-10/train/4/4_10.jpg
# processing 20100: ./cifar-10/train/4/4_10861.jpg
# processing 20200: ./cifar-10/train/4/4_11956.jpg
# processing 20300: ./cifar-10/train/4/4_12862.jpg
# processing 20400: ./cifar-10/train/4/4_13855.jpg
# processing 20500: ./cifar-10/train/4/4_14560.jpg
# processing 20600: ./cifar-10/train/4/4_153.jpg
# processing 20700: ./cifar-10/train/4/4_16181.jpg
# processing 20800: ./cifar-10/train/4/4_17044.jpg
# processing 20900: ./cifar-10/train/4/4_1804.jpg
# processing 21000: ./cifar-10/train/4/4_1882.jpg
# processing 21100: ./cifar-10/train/4/4_19704.jpg
# processing 21200: ./cifar-10/train/4/4_20608.jpg
# processing 21300: ./cifar-10/train/4/4_21495.jpg
# processing 21400: ./cifar-10/train/4/4_2238.jpg
# processing 21500: ./cifar-10/train/4/4_23329.jpg
# processing 21600: ./cifar-10/train/4/4_24421.jpg
# processing 21700: ./cifar-10/train/4/4_25403.jpg
# processing 21800: ./cifar-10/train/4/4_26434.jpg
# processing 21900: ./cifar-10/train/4/4_27221.jpg
# processing 22000: ./cifar-10/train/4/4_27990.jpg
# processing 22100: ./cifar-10/train/4/4_28797.jpg
# processing 22200: ./cifar-10/train/4/4_29679.jpg
# processing 22300: ./cifar-10/train/4/4_30589.jpg
# processing 22400: ./cifar-10/train/4/4_31536.jpg
# processing 22500: ./cifar-10/train/4/4_32413.jpg
# processing 22600: ./cifar-10/train/4/4_33185.jpg
# processing 22700: ./cifar-10/train/4/4_33961.jpg
# processing 22800: ./cifar-10/train/4/4_34895.jpg
# processing 22900: ./cifar-10/train/4/4_35868.jpg
# processing 23000: ./cifar-10/train/4/4_36843.jpg
# processing 23100: ./cifar-10/train/4/4_37707.jpg
# processing 23200: ./cifar-10/train/4/4_38603.jpg
# processing 23300: ./cifar-10/train/4/4_39467.jpg
# processing 23400: ./cifar-10/train/4/4_4032.jpg
# processing 23500: ./cifar-10/train/4/4_41191.jpg
# processing 23600: ./cifar-10/train/4/4_41982.jpg
# processing 23700: ./cifar-10/train/4/4_42903.jpg
# processing 23800: ./cifar-10/train/4/4_43640.jpg
# processing 23900: ./cifar-10/train/4/4_44689.jpg
# processing 24000: ./cifar-10/train/4/4_45571.jpg
# processing 24100: ./cifar-10/train/4/4_46415.jpg
# processing 24200: ./cifar-10/train/4/4_47348.jpg
# processing 24300: ./cifar-10/train/4/4_48338.jpg
# processing 24400: ./cifar-10/train/4/4_49292.jpg
# processing 24500: ./cifar-10/train/4/4_5345.jpg
# processing 24600: ./cifar-10/train/4/4_6251.jpg
# processing 24700: ./cifar-10/train/4/4_7099.jpg
# processing 24800: ./cifar-10/train/4/4_8233.jpg
# processing 24900: ./cifar-10/train/4/4_9155.jpg
# processing 25000: ./cifar-10/train/5/5_10014.jpg
# processing 25100: ./cifar-10/train/5/5_10945.jpg
# processing 25200: ./cifar-10/train/5/5_11723.jpg
# processing 25300: ./cifar-10/train/5/5_12649.jpg
# processing 25400: ./cifar-10/train/5/5_13598.jpg
# processing 25500: ./cifar-10/train/5/5_14700.jpg
# processing 25600: ./cifar-10/train/5/5_1567.jpg
# processing 25700: ./cifar-10/train/5/5_16566.jpg
# processing 25800: ./cifar-10/train/5/5_17595.jpg
# processing 25900: ./cifar-10/train/5/5_18416.jpg
# processing 26000: ./cifar-10/train/5/5_19169.jpg
# processing 26100: ./cifar-10/train/5/5_20031.jpg
# processing 26200: ./cifar-10/train/5/5_21006.jpg
# processing 26300: ./cifar-10/train/5/5_21889.jpg
# processing 26400: ./cifar-10/train/5/5_22834.jpg
# processing 26500: ./cifar-10/train/5/5_23724.jpg
# processing 26600: ./cifar-10/train/5/5_24650.jpg
# processing 26700: ./cifar-10/train/5/5_25588.jpg
# processing 26800: ./cifar-10/train/5/5_26377.jpg
# processing 26900: ./cifar-10/train/5/5_27257.jpg
# processing 27000: ./cifar-10/train/5/5_27991.jpg
# processing 27100: ./cifar-10/train/5/5_2884.jpg
# processing 27200: ./cifar-10/train/5/5_29755.jpg
# processing 27300: ./cifar-10/train/5/5_30482.jpg
# processing 27400: ./cifar-10/train/5/5_31347.jpg
# processing 27500: ./cifar-10/train/5/5_32277.jpg
# processing 27600: ./cifar-10/train/5/5_33067.jpg
# processing 27700: ./cifar-10/train/5/5_33986.jpg
# processing 27800: ./cifar-10/train/5/5_34854.jpg
# processing 27900: ./cifar-10/train/5/5_35751.jpg
# processing 28000: ./cifar-10/train/5/5_36617.jpg
# processing 28100: ./cifar-10/train/5/5_37527.jpg
# processing 28200: ./cifar-10/train/5/5_38392.jpg
# processing 28300: ./cifar-10/train/5/5_39381.jpg
# processing 28400: ./cifar-10/train/5/5_40272.jpg
# processing 28500: ./cifar-10/train/5/5_41190.jpg
# processing 28600: ./cifar-10/train/5/5_42323.jpg
# processing 28700: ./cifar-10/train/5/5_43129.jpg
# processing 28800: ./cifar-10/train/5/5_44104.jpg
# processing 28900: ./cifar-10/train/5/5_4487.jpg
# processing 29000: ./cifar-10/train/5/5_4572.jpg
# processing 29100: ./cifar-10/train/5/5_46532.jpg
# processing 29200: ./cifar-10/train/5/5_47268.jpg
# processing 29300: ./cifar-10/train/5/5_48199.jpg
# processing 29400: ./cifar-10/train/5/5_491.jpg
# processing 29500: ./cifar-10/train/5/5_49988.jpg
# processing 29600: ./cifar-10/train/5/5_5962.jpg
# processing 29700: ./cifar-10/train/5/5_6982.jpg
# processing 29800: ./cifar-10/train/5/5_7926.jpg
# processing 29900: ./cifar-10/train/5/5_8928.jpg
# processing 30000: ./cifar-10/train/6/6_0.jpg
# processing 30100: ./cifar-10/train/6/6_1085.jpg
# processing 30200: ./cifar-10/train/6/6_11719.jpg
# processing 30300: ./cifar-10/train/6/6_125.jpg
# processing 30400: ./cifar-10/train/6/6_13440.jpg
# processing 30500: ./cifar-10/train/6/6_14392.jpg
# processing 30600: ./cifar-10/train/6/6_15272.jpg
# processing 30700: ./cifar-10/train/6/6_16177.jpg
# processing 30800: ./cifar-10/train/6/6_17105.jpg
# processing 30900: ./cifar-10/train/6/6_17988.jpg
# processing 31000: ./cifar-10/train/6/6_18851.jpg
# processing 31100: ./cifar-10/train/6/6_1978.jpg
# processing 31200: ./cifar-10/train/6/6_20766.jpg
# processing 31300: ./cifar-10/train/6/6_21704.jpg
# processing 31400: ./cifar-10/train/6/6_22572.jpg
# processing 31500: ./cifar-10/train/6/6_23451.jpg
# processing 31600: ./cifar-10/train/6/6_24282.jpg
# processing 31700: ./cifar-10/train/6/6_25169.jpg
# processing 31800: ./cifar-10/train/6/6_26066.jpg
# processing 31900: ./cifar-10/train/6/6_26872.jpg
# processing 32000: ./cifar-10/train/6/6_27971.jpg
# processing 32100: ./cifar-10/train/6/6_28956.jpg
# processing 32200: ./cifar-10/train/6/6_29798.jpg
# processing 32300: ./cifar-10/train/6/6_30812.jpg
# processing 32400: ./cifar-10/train/6/6_31672.jpg
# processing 32500: ./cifar-10/train/6/6_32565.jpg
# processing 32600: ./cifar-10/train/6/6_33466.jpg
# processing 32700: ./cifar-10/train/6/6_3435.jpg
# processing 32800: ./cifar-10/train/6/6_35136.jpg
# processing 32900: ./cifar-10/train/6/6_361.jpg
# processing 33000: ./cifar-10/train/6/6_36913.jpg
# processing 33100: ./cifar-10/train/6/6_37846.jpg
# processing 33200: ./cifar-10/train/6/6_38736.jpg
# processing 33300: ./cifar-10/train/6/6_39630.jpg
# processing 33400: ./cifar-10/train/6/6_40568.jpg
# processing 33500: ./cifar-10/train/6/6_4144.jpg
# processing 33600: ./cifar-10/train/6/6_42340.jpg
# processing 33700: ./cifar-10/train/6/6_43250.jpg
# processing 33800: ./cifar-10/train/6/6_4409.jpg
# processing 33900: ./cifar-10/train/6/6_45155.jpg
# processing 34000: ./cifar-10/train/6/6_4605.jpg
# processing 34100: ./cifar-10/train/6/6_46971.jpg
# processing 34200: ./cifar-10/train/6/6_47965.jpg
# processing 34300: ./cifar-10/train/6/6_48888.jpg
# processing 34400: ./cifar-10/train/6/6_49667.jpg
# processing 34500: ./cifar-10/train/6/6_5582.jpg
# processing 34600: ./cifar-10/train/6/6_6526.jpg
# processing 34700: ./cifar-10/train/6/6_7272.jpg
# processing 34800: ./cifar-10/train/6/6_8206.jpg
# processing 34900: ./cifar-10/train/6/6_9180.jpg
# processing 35000: ./cifar-10/train/7/7_10028.jpg
# processing 35100: ./cifar-10/train/7/7_10813.jpg
# processing 35200: ./cifar-10/train/7/7_11697.jpg
# processing 35300: ./cifar-10/train/7/7_12751.jpg
# processing 35400: ./cifar-10/train/7/7_13516.jpg
# processing 35500: ./cifar-10/train/7/7_14489.jpg
# processing 35600: ./cifar-10/train/7/7_15283.jpg
# processing 35700: ./cifar-10/train/7/7_16138.jpg
# processing 35800: ./cifar-10/train/7/7_17160.jpg
# processing 35900: ./cifar-10/train/7/7_17989.jpg
# processing 36000: ./cifar-10/train/7/7_1891.jpg
# processing 36100: ./cifar-10/train/7/7_19691.jpg
# processing 36200: ./cifar-10/train/7/7_20618.jpg
# processing 36300: ./cifar-10/train/7/7_21557.jpg
# processing 36400: ./cifar-10/train/7/7_22454.jpg
# processing 36500: ./cifar-10/train/7/7_23310.jpg
# processing 36600: ./cifar-10/train/7/7_24181.jpg
# processing 36700: ./cifar-10/train/7/7_25079.jpg
# processing 36800: ./cifar-10/train/7/7_25948.jpg
# processing 36900: ./cifar-10/train/7/7_26831.jpg
# processing 37000: ./cifar-10/train/7/7_27775.jpg
# processing 37100: ./cifar-10/train/7/7_28578.jpg
# processing 37200: ./cifar-10/train/7/7_29588.jpg
# processing 37300: ./cifar-10/train/7/7_30417.jpg
# processing 37400: ./cifar-10/train/7/7_31381.jpg
# processing 37500: ./cifar-10/train/7/7_32282.jpg
# processing 37600: ./cifar-10/train/7/7_33191.jpg
# processing 37700: ./cifar-10/train/7/7_34226.jpg
# processing 37800: ./cifar-10/train/7/7_35120.jpg
# processing 37900: ./cifar-10/train/7/7_36114.jpg
# processing 38000: ./cifar-10/train/7/7_37019.jpg
# processing 38100: ./cifar-10/train/7/7_37897.jpg
# processing 38200: ./cifar-10/train/7/7_38737.jpg
# processing 38300: ./cifar-10/train/7/7_39582.jpg
# processing 38400: ./cifar-10/train/7/7_40567.jpg
# processing 38500: ./cifar-10/train/7/7_41506.jpg
# processing 38600: ./cifar-10/train/7/7_42423.jpg
# processing 38700: ./cifar-10/train/7/7_43316.jpg
# processing 38800: ./cifar-10/train/7/7_44135.jpg
# processing 38900: ./cifar-10/train/7/7_45065.jpg
# processing 39000: ./cifar-10/train/7/7_46027.jpg
# processing 39100: ./cifar-10/train/7/7_47046.jpg
# processing 39200: ./cifar-10/train/7/7_47941.jpg
# processing 39300: ./cifar-10/train/7/7_48918.jpg
# processing 39400: ./cifar-10/train/7/7_49801.jpg
# processing 39500: ./cifar-10/train/7/7_5620.jpg
# processing 39600: ./cifar-10/train/7/7_6481.jpg
# processing 39700: ./cifar-10/train/7/7_7314.jpg
# processing 39800: ./cifar-10/train/7/7_8202.jpg
# processing 39900: ./cifar-10/train/7/7_8980.jpg
# processing 40000: ./cifar-10/train/8/8_100.jpg
# processing 40100: ./cifar-10/train/8/8_10805.jpg
# processing 40200: ./cifar-10/train/8/8_11706.jpg
# processing 40300: ./cifar-10/train/8/8_12615.jpg
# processing 40400: ./cifar-10/train/8/8_13574.jpg
# processing 40500: ./cifar-10/train/8/8_14442.jpg
# processing 40600: ./cifar-10/train/8/8_15438.jpg
# processing 40700: ./cifar-10/train/8/8_16414.jpg
# processing 40800: ./cifar-10/train/8/8_17277.jpg
# processing 40900: ./cifar-10/train/8/8_18190.jpg
# processing 41000: ./cifar-10/train/8/8_19102.jpg
# processing 41100: ./cifar-10/train/8/8_19995.jpg
# processing 41200: ./cifar-10/train/8/8_20889.jpg
# processing 41300: ./cifar-10/train/8/8_21699.jpg
# processing 41400: ./cifar-10/train/8/8_22714.jpg
# processing 41500: ./cifar-10/train/8/8_23666.jpg
# processing 41600: ./cifar-10/train/8/8_24481.jpg
# processing 41700: ./cifar-10/train/8/8_25412.jpg
# processing 41800: ./cifar-10/train/8/8_26334.jpg
# processing 41900: ./cifar-10/train/8/8_2735.jpg
# processing 42000: ./cifar-10/train/8/8_28269.jpg
# processing 42100: ./cifar-10/train/8/8_2942.jpg
# processing 42200: ./cifar-10/train/8/8_30262.jpg
# processing 42300: ./cifar-10/train/8/8_31125.jpg
# processing 42400: ./cifar-10/train/8/8_31810.jpg
# processing 42500: ./cifar-10/train/8/8_32609.jpg
# processing 42600: ./cifar-10/train/8/8_33446.jpg
# processing 42700: ./cifar-10/train/8/8_34473.jpg
# processing 42800: ./cifar-10/train/8/8_35374.jpg
# processing 42900: ./cifar-10/train/8/8_36390.jpg
# processing 43000: ./cifar-10/train/8/8_37348.jpg
# processing 43100: ./cifar-10/train/8/8_3832.jpg
# processing 43200: ./cifar-10/train/8/8_39079.jpg
# processing 43300: ./cifar-10/train/8/8_39937.jpg
# processing 43400: ./cifar-10/train/8/8_40785.jpg
# processing 43500: ./cifar-10/train/8/8_41744.jpg
# processing 43600: ./cifar-10/train/8/8_42676.jpg
# processing 43700: ./cifar-10/train/8/8_43505.jpg
# processing 43800: ./cifar-10/train/8/8_4466.jpg
# processing 43900: ./cifar-10/train/8/8_45726.jpg
# processing 44000: ./cifar-10/train/8/8_46479.jpg
# processing 44100: ./cifar-10/train/8/8_47393.jpg
# processing 44200: ./cifar-10/train/8/8_4815.jpg
# processing 44300: ./cifar-10/train/8/8_4892.jpg
# processing 44400: ./cifar-10/train/8/8_49757.jpg
# processing 44500: ./cifar-10/train/8/8_5630.jpg
# processing 44600: ./cifar-10/train/8/8_6501.jpg
# processing 44700: ./cifar-10/train/8/8_7384.jpg
# processing 44800: ./cifar-10/train/8/8_8267.jpg
# processing 44900: ./cifar-10/train/8/8_9076.jpg
# processing 45000: ./cifar-10/train/9/9_1.jpg
# processing 45100: ./cifar-10/train/9/9_10943.jpg
# processing 45200: ./cifar-10/train/9/9_11828.jpg
# processing 45300: ./cifar-10/train/9/9_12760.jpg
# processing 45400: ./cifar-10/train/9/9_13699.jpg
# processing 45500: ./cifar-10/train/9/9_14563.jpg
# processing 45600: ./cifar-10/train/9/9_15480.jpg
# processing 45700: ./cifar-10/train/9/9_16454.jpg
# processing 45800: ./cifar-10/train/9/9_17241.jpg
# processing 45900: ./cifar-10/train/9/9_18166.jpg
# processing 46000: ./cifar-10/train/9/9_19114.jpg
# processing 46100: ./cifar-10/train/9/9_2.jpg
# processing 46200: ./cifar-10/train/9/9_20944.jpg
# processing 46300: ./cifar-10/train/9/9_21729.jpg
# processing 46400: ./cifar-10/train/9/9_22598.jpg
# processing 46500: ./cifar-10/train/9/9_23551.jpg
# processing 46600: ./cifar-10/train/9/9_24310.jpg
# processing 46700: ./cifar-10/train/9/9_25387.jpg
# processing 46800: ./cifar-10/train/9/9_26384.jpg
# processing 46900: ./cifar-10/train/9/9_27070.jpg
# processing 47000: ./cifar-10/train/9/9_27837.jpg
# processing 47100: ./cifar-10/train/9/9_28781.jpg
# processing 47200: ./cifar-10/train/9/9_29580.jpg
# processing 47300: ./cifar-10/train/9/9_30615.jpg
# processing 47400: ./cifar-10/train/9/9_3143.jpg
# processing 47500: ./cifar-10/train/9/9_32242.jpg
# processing 47600: ./cifar-10/train/9/9_33344.jpg
# processing 47700: ./cifar-10/train/9/9_34232.jpg
# processing 47800: ./cifar-10/train/9/9_3510.jpg
# processing 47900: ./cifar-10/train/9/9_36029.jpg
# processing 48000: ./cifar-10/train/9/9_36865.jpg
# processing 48100: ./cifar-10/train/9/9_37629.jpg
# processing 48200: ./cifar-10/train/9/9_3876.jpg
# processing 48300: ./cifar-10/train/9/9_39688.jpg
# processing 48400: ./cifar-10/train/9/9_4041.jpg
# processing 48500: ./cifar-10/train/9/9_41316.jpg
# processing 48600: ./cifar-10/train/9/9_4223.jpg
# processing 48700: ./cifar-10/train/9/9_43199.jpg
# processing 48800: ./cifar-10/train/9/9_4407.jpg
# processing 48900: ./cifar-10/train/9/9_44983.jpg
# processing 49000: ./cifar-10/train/9/9_4586.jpg
# processing 49100: ./cifar-10/train/9/9_46752.jpg
# processing 49200: ./cifar-10/train/9/9_47583.jpg
# processing 49300: ./cifar-10/train/9/9_48455.jpg
# processing 49400: ./cifar-10/train/9/9_49398.jpg
# processing 49500: ./cifar-10/train/9/9_5244.jpg
# processing 49600: ./cifar-10/train/9/9_6066.jpg
# processing 49700: ./cifar-10/train/9/9_703.jpg
# processing 49800: ./cifar-10/train/9/9_8087.jpg
# processing 49900: ./cifar-10/train/9/9_8959.jpg
# done: 50000
# 10000
# processing 0: ./cifar-10/test/0/0_10.jpg
# processing 100: ./cifar-10/test/0/0_1949.jpg
# processing 200: ./cifar-10/test/0/0_2794.jpg
# processing 300: ./cifar-10/test/0/0_3680.jpg
# processing 400: ./cifar-10/test/0/0_4639.jpg
# processing 500: ./cifar-10/test/0/0_5491.jpg
# processing 600: ./cifar-10/test/0/0_642.jpg
# processing 700: ./cifar-10/test/0/0_7315.jpg
# processing 800: ./cifar-10/test/0/0_8210.jpg
# processing 900: ./cifar-10/test/0/0_9172.jpg
# processing 1000: ./cifar-10/test/1/1_1005.jpg
# processing 1100: ./cifar-10/test/1/1_1806.jpg
# processing 1200: ./cifar-10/test/1/1_2859.jpg
# processing 1300: ./cifar-10/test/1/1_3715.jpg
# processing 1400: ./cifar-10/test/1/1_4611.jpg
# processing 1500: ./cifar-10/test/1/1_5431.jpg
# processing 1600: ./cifar-10/test/1/1_6552.jpg
# processing 1700: ./cifar-10/test/1/1_7394.jpg
# processing 1800: ./cifar-10/test/1/1_8248.jpg
# processing 1900: ./cifar-10/test/1/1_9125.jpg
# processing 2000: ./cifar-10/test/2/2_1038.jpg
# processing 2100: ./cifar-10/test/2/2_1929.jpg
# processing 2200: ./cifar-10/test/2/2_2691.jpg
# processing 2300: ./cifar-10/test/2/2_3541.jpg
# processing 2400: ./cifar-10/test/2/2_4388.jpg
# processing 2500: ./cifar-10/test/2/2_5492.jpg
# processing 2600: ./cifar-10/test/2/2_6457.jpg
# processing 2700: ./cifar-10/test/2/2_731.jpg
# processing 2800: ./cifar-10/test/2/2_8087.jpg
# processing 2900: ./cifar-10/test/2/2_9039.jpg
# processing 3000: ./cifar-10/test/3/3_0.jpg
# processing 3100: ./cifar-10/test/3/3_1957.jpg
# processing 3200: ./cifar-10/test/3/3_2897.jpg
# processing 3300: ./cifar-10/test/3/3_3835.jpg
# processing 3400: ./cifar-10/test/3/3_4705.jpg
# processing 3500: ./cifar-10/test/3/3_558.jpg
# processing 3600: ./cifar-10/test/3/3_646.jpg
# processing 3700: ./cifar-10/test/3/3_7352.jpg
# processing 3800: ./cifar-10/test/3/3_8201.jpg
# processing 3900: ./cifar-10/test/3/3_8996.jpg
# processing 4000: ./cifar-10/test/4/4_100.jpg
# processing 4100: ./cifar-10/test/4/4_1827.jpg
# processing 4200: ./cifar-10/test/4/4_2778.jpg
# processing 4300: ./cifar-10/test/4/4_3627.jpg
# processing 4400: ./cifar-10/test/4/4_4523.jpg
# processing 4500: ./cifar-10/test/4/4_5345.jpg
# processing 4600: ./cifar-10/test/4/4_6161.jpg
# processing 4700: ./cifar-10/test/4/4_7081.jpg
# processing 4800: ./cifar-10/test/4/4_804.jpg
# processing 4900: ./cifar-10/test/4/4_8989.jpg
# processing 5000: ./cifar-10/test/5/5_1000.jpg
# processing 5100: ./cifar-10/test/5/5_190.jpg
# processing 5200: ./cifar-10/test/5/5_275.jpg
# processing 5300: ./cifar-10/test/5/5_3622.jpg
# processing 5400: ./cifar-10/test/5/5_4623.jpg
# processing 5500: ./cifar-10/test/5/5_5463.jpg
# processing 5600: ./cifar-10/test/5/5_6199.jpg
# processing 5700: ./cifar-10/test/5/5_7127.jpg
# processing 5800: ./cifar-10/test/5/5_8025.jpg
# processing 5900: ./cifar-10/test/5/5_9084.jpg
# processing 6000: ./cifar-10/test/6/6_1009.jpg
# processing 6100: ./cifar-10/test/6/6_1892.jpg
# processing 6200: ./cifar-10/test/6/6_2848.jpg
# processing 6300: ./cifar-10/test/6/6_3840.jpg
# processing 6400: ./cifar-10/test/6/6_4772.jpg
# processing 6500: ./cifar-10/test/6/6_5564.jpg
# processing 6600: ./cifar-10/test/6/6_6471.jpg
# processing 6700: ./cifar-10/test/6/6_7371.jpg
# processing 6800: ./cifar-10/test/6/6_8306.jpg
# processing 6900: ./cifar-10/test/6/6_9068.jpg
# processing 7000: ./cifar-10/test/7/7_1037.jpg
# processing 7100: ./cifar-10/test/7/7_20.jpg
# processing 7200: ./cifar-10/test/7/7_2959.jpg
# processing 7300: ./cifar-10/test/7/7_386.jpg
# processing 7400: ./cifar-10/test/7/7_4688.jpg
# processing 7500: ./cifar-10/test/7/7_5541.jpg
# processing 7600: ./cifar-10/test/7/7_6356.jpg
# processing 7700: ./cifar-10/test/7/7_732.jpg
# processing 7800: ./cifar-10/test/7/7_8235.jpg
# processing 7900: ./cifar-10/test/7/7_9186.jpg
# processing 8000: ./cifar-10/test/8/8_1.jpg
# processing 8100: ./cifar-10/test/8/8_1809.jpg
# processing 8200: ./cifar-10/test/8/8_260.jpg
# processing 8300: ./cifar-10/test/8/8_3625.jpg
# processing 8400: ./cifar-10/test/8/8_4497.jpg
# processing 8500: ./cifar-10/test/8/8_5662.jpg
# processing 8600: ./cifar-10/test/8/8_6602.jpg
# processing 8700: ./cifar-10/test/8/8_7485.jpg
# processing 8800: ./cifar-10/test/8/8_8311.jpg
# processing 8900: ./cifar-10/test/8/8_9130.jpg
# processing 9000: ./cifar-10/test/9/9_1008.jpg
# processing 9100: ./cifar-10/test/9/9_1916.jpg
# processing 9200: ./cifar-10/test/9/9_285.jpg
# processing 9300: ./cifar-10/test/9/9_3687.jpg
# processing 9400: ./cifar-10/test/9/9_4536.jpg
# processing 9500: ./cifar-10/test/9/9_5391.jpg
# processing 9600: ./cifar-10/test/9/9_6337.jpg
# processing 9700: ./cifar-10/test/9/9_7431.jpg
# processing 9800: ./cifar-10/test/9/9_8276.jpg
# processing 9900: ./cifar-10/test/9/9_921.jpg
# done: 10000

# %%
def compute_accuracy(v_xs, v_ys):
    global prediction
    y_pre = sess.run(prediction, feed_dict={xs: v_xs, keep_prob: 1})
    correct_prediction = tf.equal(tf.argmax(y_pre,1), tf.argmax(v_ys,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    result = sess.run(accuracy, feed_dict={xs: v_xs, ys: v_ys, keep_prob: 1})
    return result

def compute_loss(v_xs, v_ys):
    avg_loss_value = sess.run(avg_loss, feed_dict={xs: v_xs, ys: v_ys, keep_prob: 0.5})
    return avg_loss_value

def conv_weight_variable(kernal_shape,input_shape):
    initial = tf.truncated_normal(kernal_shape, stddev=numpy.sqrt(2.0 / (input_shape[0] * input_shape[1] * input_shape[2])))
    return tf.Variable(initial)

def fc_weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=numpy.sqrt(2.0 / shape[0]))
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.0, shape=shape)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def conv_batch_normal(x,b,n_filter,is_train=1):
    epsilon = 1e-5
    gamma = tf.Variable(initial_value=tf.constant(1.0, shape=[n_filter]),trainable=True)
    batch_mean, batch_var = tf.nn.moments(x, axes=[0, 1, 2], name='moments')
    ema = tf.train.ExponentialMovingAverage(decay=0.5)
  
    def mean_var_with_update():      
        ema_apply_op = ema.apply([batch_mean, batch_var])
        with tf.control_dependencies([ema_apply_op]):
            return tf.identity(batch_mean), tf.identity(batch_var)

    mean, variance = tf.cond(tf.greater(is_train,0), mean_var_with_update, lambda: (ema.average(batch_mean), ema.average(batch_var)))

    return tf.nn.batch_normalization(x, mean, variance, b, gamma, epsilon)

def fc_batch_normal(x,b,hidden_dim,is_train=1):
    epsilon = 1e-5
    gamma = tf.Variable(initial_value=tf.constant(1.0, shape=[hidden_dim]),trainable=True)
    batch_mean, batch_var = tf.nn.moments(x, axes=[0], name='moments')
    ema = tf.train.ExponentialMovingAverage(decay=0.5)
  
    def mean_var_with_update():      
        ema_apply_op = ema.apply([batch_mean, batch_var])
        with tf.control_dependencies([ema_apply_op]):
            return tf.identity(batch_mean), tf.identity(batch_var)

    mean, variance = tf.cond(tf.greater(is_train,0), mean_var_with_update, lambda: (ema.average(batch_mean), ema.average(batch_var)))

    return tf.nn.batch_normalization(x, mean, variance, b, gamma, epsilon) 

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

# %%
# define placeholder for inputs to network
xs = tf.placeholder(tf.float32, [None, image_size, image_size, 3]) 
ys = tf.placeholder(tf.float32, [None, 10])
keep_prob = tf.placeholder(tf.float32)


## conv1 layer ##
W_conv1 = conv_weight_variable([3,3,3,64],[image_size,image_size,3])
weight_decay1 = tf.multiply(tf.nn.l2_loss(W_conv1), 1e-4)
tf.add_to_collection('losses', weight_decay1)
b_conv1 = bias_variable([64])
h_conv1 = tf.nn.relu(conv_batch_normal(conv2d(xs, W_conv1),b_conv1,64)) 
h_pool1 = max_pool_2x2(h_conv1)                         
norm1 = tf.nn.local_response_normalization(h_pool1, depth_radius=4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

## conv2 layer ##
W_conv2 = conv_weight_variable([3,3,64,128],[int(image_size/2),int(image_size/2),64]) 
weight_decay2 = tf.multiply(tf.nn.l2_loss(W_conv2), 1e-4)
tf.add_to_collection('losses', weight_decay2)
b_conv2 = bias_variable([128])
h_conv2 = tf.nn.relu(conv_batch_normal(conv2d(norm1, W_conv2),b_conv2,128))
h_pool2 = max_pool_2x2(h_conv2)
norm2 = tf.nn.local_response_normalization(h_pool2, depth_radius=4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

## conv3 layer ##
W_conv3 = conv_weight_variable([3,3,128,256],[int(image_size/4),int(image_size/4),128]) 
weight_decay3 = tf.multiply(tf.nn.l2_loss(W_conv3), 1e-4)
tf.add_to_collection('losses', weight_decay3)
b_conv3 = bias_variable([256])
h_conv3 = tf.nn.relu(conv_batch_normal(conv2d(norm2, W_conv3),b_conv3,256))
h_pool3 = max_pool_2x2(h_conv3)                        
norm3 = tf.nn.local_response_normalization(h_pool3, depth_radius=4, bias=1.0, alpha=0.001 / 9.0, beta=0.75)

## fc1 layer ##
W_fc1 = fc_weight_variable([int(image_size/8)*int(image_size/8)*256, 1024])
b_fc1 = bias_variable([1024])
h_norm3_flat = tf.reshape(norm3, [-1,int(image_size/8)*int(image_size/8)*256])
intermediate_fc1 = fc_batch_normal(tf.matmul(h_norm3_flat, W_fc1),b_fc1,1024)
h_fc1_drop = tf.nn.dropout(intermediate_fc1, keep_prob)
h_fc1 = tf.nn.relu(h_fc1_drop)

## fc2 layer ##
W_fc2 = fc_weight_variable([1024, 10])
b_fc2 = bias_variable([10])
intermediate_fc2 = tf.matmul(h_fc1, W_fc2) + b_fc2
h_fc2 = intermediate_fc2

## softmax logic layer ##
prediction = tf.nn.softmax(h_fc2)

# %%
# the error between prediction and real data
cross_entropy = tf.reduce_sum(tf.nn.softmax_cross_entropy_with_logits(logits=h_fc2, labels=ys))
tf.add_to_collection('losses', cross_entropy)

avg_loss = tf.add_n(tf.get_collection('losses'))

train_step1 = tf.train.AdamOptimizer(lr1).minimize(avg_loss)
train_step2 = tf.train.AdamOptimizer(lr2).minimize(avg_loss)
train_step3 = tf.train.AdamOptimizer(lr3).minimize(avg_loss)
train_step4 = tf.train.AdamOptimizer(lr4).minimize(avg_loss)

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)
saver = tf.train.Saver()

acc_mat = []
acc_iter = []
loss_mat = []
loss_iter = []

for i in range(iterration):
            
    batch_xs, batch_ys = cifar10.train.next_batch(batch_size, shuffle=True, flip=True, whiten=True, noise=False,crop=True,crop_test=False)
    
    #变化学习率
    if(0<= i <= 500):
        sess.run(train_step1, feed_dict={xs: batch_xs, ys: batch_ys, keep_prob: 0.5})
    elif(500 < i <=3000):
        sess.run(train_step2, feed_dict={xs: batch_xs, ys: batch_ys, keep_prob: 0.5})
    elif(3000 < i <=6000):
        sess.run(train_step3, feed_dict={xs: batch_xs, ys: batch_ys, keep_prob: 0.5})        
    else:
        sess.run(train_step4, feed_dict={xs: batch_xs, ys: batch_ys, keep_prob: 0.5})
    
    if i % 100 == 0:
        batch_xt, batch_yt = cifar10.test.next_batch(1280, shuffle=True, flip=False, whiten=True, noise=False,crop=False,crop_test=True)
        
        Test_Accuracy = compute_accuracy(batch_xt, batch_yt)
        acc_mat.append(Test_Accuracy)
        acc_iter.append(i)
        print("Test Accuracy:",Test_Accuracy)
        
        Training_Loss = compute_loss(batch_xs, batch_ys)
        loss_mat.append(Training_Loss)
        loss_iter.append(i)
        print("Training Loss:",Training_Loss)
        
        saver_path = saver.save(sess,"model/model.ckpt")
        print("model has been saved.")
        print("Time:",time.asctime(time.localtime(time.time())))
        
        #绘制loss曲线
        plt.title('Training Loss')
        plt.xlabel('iter')
        plt.ylabel('loss')
        plt.plot(loss_iter,loss_mat,'r',label='change of loss')
        plt.grid()
        plt.show()
        
        #绘制准确率曲线
        plt.title('Test Accuracy')
        plt.xlabel('iter')
        plt.ylabel('Accuracy')
        plt.plot(acc_iter,acc_mat,'b',label='change of Accuracy')
        plt.grid()
        plt.show()        
        
    print("Iteration:",i)

sess.close()
# Out:
# Test Accuracy: 0.1
# Training Loss: 2632.89
# model has been saved.
# Time: Fri Oct 12 00:35:04 2018
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27
# Iteration: 28
# Iteration: 29
# Iteration: 30
# Iteration: 31
# Iteration: 32
# Iteration: 33
# Iteration: 34
# Iteration: 35
# Iteration: 36
# Iteration: 37
# Iteration: 38
# Iteration: 39
# Iteration: 40
# Iteration: 41
# Iteration: 42
# Iteration: 43
# Iteration: 44
# Iteration: 45
# Iteration: 46
# Iteration: 47
# Iteration: 48
# Iteration: 49
# Iteration: 50
# Iteration: 51
# Iteration: 52
# Iteration: 53
# Iteration: 54
# Iteration: 55
# Iteration: 56
# Iteration: 57
# Iteration: 58
# Iteration: 59
# Iteration: 60
# Iteration: 61
# Iteration: 62
# Iteration: 63
# Iteration: 64
# Iteration: 65
# Iteration: 66
# Iteration: 67
# Iteration: 68
# Iteration: 69
# Iteration: 70
# Iteration: 71
# Iteration: 72
# Iteration: 73
# Iteration: 74
# Iteration: 75
# Iteration: 76
# Iteration: 77
# Iteration: 78
# Iteration: 79
# Iteration: 80
# Iteration: 81
# Iteration: 82
# Iteration: 83
# Iteration: 84
# Iteration: 85
# Iteration: 86
# Iteration: 87
# Iteration: 88
# Iteration: 89
# Iteration: 90
# Iteration: 91
# Iteration: 92
# Iteration: 93
# Iteration: 94
# Iteration: 95
# Iteration: 96
# Iteration: 97
# Iteration: 98
# Iteration: 99
# Test Accuracy: 0.227344
# Training Loss: 260.953
# model has been saved.
# Time: Fri Oct 12 00:37:33 2018
# Iteration: 100
# Iteration: 101
# Iteration: 102
# Iteration: 103
# Iteration: 104
# Iteration: 105
# Iteration: 106
# Iteration: 107
# Iteration: 108
# Iteration: 109
# Iteration: 110
# Iteration: 111
# Iteration: 112
# Iteration: 113
# Iteration: 114
# Iteration: 115
# Iteration: 116
# Iteration: 117
# Iteration: 118
# Iteration: 119
# Iteration: 120
# Iteration: 121
# Iteration: 122
# Iteration: 123
# Iteration: 124
# Iteration: 125
# Iteration: 126
# Iteration: 127
# Iteration: 128
# Iteration: 129
# Iteration: 130
# Iteration: 131
# Iteration: 132
# Iteration: 133
# Iteration: 134
# Iteration: 135
# Iteration: 136
# Iteration: 137
# Iteration: 138
# Iteration: 139
# Iteration: 140
# Iteration: 141
# Iteration: 142
# Iteration: 143
# Iteration: 144
# Iteration: 145
# Iteration: 146
# Iteration: 147
# Iteration: 148
# Iteration: 149
# Iteration: 150
# Iteration: 151
# Iteration: 152
# Iteration: 153
# Iteration: 154
# Iteration: 155
# Iteration: 156
# Iteration: 157
# Iteration: 158
# Iteration: 159
# Iteration: 160
# Iteration: 161
# Iteration: 162
# Iteration: 163
# Iteration: 164
# Iteration: 165
# Iteration: 166
# Iteration: 167
# Iteration: 168
# Iteration: 169
# Iteration: 170
# Iteration: 171
# Iteration: 172
# Iteration: 173
# Iteration: 174
# Iteration: 175
# Iteration: 176
# Iteration: 177
# Iteration: 178
# Iteration: 179
# Iteration: 180
# Iteration: 181
# Iteration: 182
# Iteration: 183
# Iteration: 184
# Iteration: 185
# Iteration: 186
# Iteration: 187
# Iteration: 188
# Iteration: 189
# Iteration: 190
# Iteration: 191
# Iteration: 192
# Iteration: 193
# Iteration: 194
# Iteration: 195
# Iteration: 196
# Iteration: 197
# Iteration: 198
# Iteration: 199
# Test Accuracy: 0.309375
# Training Loss: 245.823
# model has been saved.
# Time: Fri Oct 12 00:40:08 2018
# Iteration: 200
# Iteration: 201
# Iteration: 202
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5040f8c56964> in <module>()
#      15     #变化学习率
#      16     if(0<= i <= 500):
# ---> 17         sess.run(train_step1, feed_dict={xs: batch_xs, ys: batch_ys, keep_prob: 0.5})
#      18     elif(500 < i <=3000):
#      19         sess.run(train_step2, feed_dict={xs: batch_xs, ys: batch_ys, keep_prob: 0.5})
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
